# %%
import pandas as pd

# %%
df= pd.read_csv("/users/Tushnik/Documents/DataEinstein folder/TestBattingAverage.csv")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 2      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 3      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 4     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 63   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 64  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 65  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 66    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 67   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s  Unnamed: 15  Unnamed: 16 Unnamed: 17
# ...

# %%
#rename columns in a list
df=df.rename(columns={"NO":"Not_Outs","HS":"Highest_Inns_Score","BF":"Balls_Faced","SR":"Batting_Strike_Rate","Mat":"Matches"})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 2    HC Brook (ENG)  2022-2023       12    20         1  1181
# 3    AC Voges (AUS)  2015-2016       20    31         7  1485
# 4   RG Pollock (SA)  1963-1970       23    41         4  2256
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  \
# 0                334  99.94       9800+                58.60   29  13  7  626
# 1                334  99.94       9800+                58.60   29  13  7  626
# 2                186  62.15        1287                91.76    4   7  1  141
# 3               269*  61.87        2667                55.68    5   4  2  186
# 4                274  60.97       1707+                54.48    7  11  1  246
#
#    6s  Unnamed: 15  Unnamed: 16 Unnamed: 17
# 0   6          NaN          NaN         NaN
# ...

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Unnamed: 15             True
# Unnamed: 16             True
# Unnamed: 17             True
# dtype: bool

# %%
df.drop(columns=["Unnamed: 15","Unnamed: 16","Unnamed: 17"],inplace=True)

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 2      HC Brook (ENG)  2022-2023       12    20         1  1181
# 3      AC Voges (AUS)  2015-2016       20    31         7  1485
# 4     RG Pollock (SA)  1963-1970       23    41         4  2256
# ..                ...        ...      ...   ...       ...   ...
# 63   KD Walters (AUS)  1965-1981       74   125        14  5357
# 64  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 65  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 66    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 67   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
df[df["Balls_Faced"].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 10        ED Weekes (WI)  1948-1958       48    81         5  4455
# 17       CL Walcott (WI)  1948-1960       44    74         7  3798
# 60  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 10                207  58.61         NaN                  NaN   15  19  6
# 17                220  56.68         NaN                  NaN   15  14  1
# 60               144*  48.79         NaN                  NaN    5   6  3
#
#      4s  6s
# 10  258   2
# 17  107  11
# 60   51   0

# %%
df["Balls_Faced"]=df['Balls_Faced'].fillna(0)

# %%
df[df["Batting_Strike_Rate"].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 10        ED Weekes (WI)  1948-1958       48    81         5  4455
# 17       CL Walcott (WI)  1948-1960       44    74         7  3798
# 60  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 10                207  58.61           0                  NaN   15  19  6
# 17                220  56.68           0                  NaN   15  14  1
# 60               144*  48.79           0                  NaN    5   6  3
#
#      4s  6s
# 10  258   2
# 17  107  11
# 60   51   0

# %%
df["Batting_Strike_Rate"]=df['Batting_Strike_Rate'].fillna(0)

# %%
df[df["Player"]=="Hon.FS Jackson (ENG)"]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 60  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  4s  \
# 60               144*  48.79           0                  0.0    5   6  3  51
#
#     6s
# 60   0

# %%
#drop duplicates
df.duplicated().sum()
# Out:
# 4

# %%
df[df["Player"].duplicated()==1]
# Out:
#                  Player       Span  Matches  Inns  Not_Outs   Runs  \
# 1      DG Bradman (AUS)  1928-1948       52    80        10   6996
# 9   KF Barrington (ENG)  1955-1968       82   131        15   6806
# 24      VG Kambli (IND)  1993-1995       17    21         1   1084
# 35     RT Ponting (AUS)  1995-2012      168   287        29  13378
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 1                 334  99.94       9800+                58.60   29  13   7
# 9                 256  58.67       4957+                42.42   20  35   5
# 24                227  54.20        1823                59.46    4   3   3
# 35                257  51.85       22782                58.72   41  62  17
#
#       4s  6s
# 1    626   6
# 9    591  27
# 24   124   6
# 35  1509  73

# %%
df[df["Player"].isin(["DG Bradman (AUS)","KF Barrington (ENG)","VG Kambli (IND)","RT Ponting (AUS)"])]
# Out:
#                  Player       Span  Matches  Inns  Not_Outs   Runs  \
# 0      DG Bradman (AUS)  1928-1948       52    80        10   6996
# 1      DG Bradman (AUS)  1928-1948       52    80        10   6996
# 8   KF Barrington (ENG)  1955-1968       82   131        15   6806
# 9   KF Barrington (ENG)  1955-1968       82   131        15   6806
# 23      VG Kambli (IND)  1993-1995       17    21         1   1084
# 24      VG Kambli (IND)  1993-1995       17    21         1   1084
# 34     RT Ponting (AUS)  1995-2012      168   287        29  13378
# 35     RT Ponting (AUS)  1995-2012      168   287        29  13378
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# 1                 334  99.94       9800+                58.60   29  13   7
# 8                 256  58.67       4957+                42.42   20  35   5
# ...

# %%
df=df.drop_duplicates()

# %%
df[df["Player"].isin(["DG Bradman (AUS)","KF Barrington (ENG)","VG Kambli (IND)","RT Ponting (AUS)"])]
# Out:
#                  Player       Span  Matches  Inns  Not_Outs   Runs  \
# 0      DG Bradman (AUS)  1928-1948       52    80        10   6996
# 8   KF Barrington (ENG)  1955-1968       82   131        15   6806
# 23      VG Kambli (IND)  1993-1995       17    21         1   1084
# 34     RT Ponting (AUS)  1995-2012      168   287        29  13378
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# 8                 256  58.67       4957+                42.42   20  35   5
# 23                227  54.20        1823                59.46    4   3   3
# 34                257  51.85       22782                58.72   41  62  17
#
#       4s  6s
# 0    626   6
# 8    591  27
# 23   124   6
# 34  1509  73

# %%
#split up span into start and end date
df["Span"]
# Out:
# 0     1928-1948
# 2     2022-2023
# 3     2015-2016
# 4     1963-1970
# 5     1930-1954
#         ...
# 63    1965-1981
# 64    2002-2014
# 65    1924-1934
# 66    1930-1938
# 67    1928-1934
# Name: Span, Length: 64, dtype: object

# %%
df["Span"].str.split(pat="-")
# Out:
# 0     [1928, 1948]
# 2     [2022, 2023]
# 3     [2015, 2016]
# 4     [1963, 1970]
# 5     [1930, 1954]
#           ...
# 63    [1965, 1981]
# 64    [2002, 2014]
# 65    [1924, 1934]
# 66    [1930, 1938]
# 67    [1928, 1934]
# Name: Span, Length: 64, dtype: object

# %%
df["Rookie_Year"]=df['Span'].str.split(pat="-").str[0]
# Out:
# C:\Users\Tushnik\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df["Final_Year"]=df['Span'].str.split(pat="-").str[1]
# Out:
# C:\Users\Tushnik\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 2      HC Brook (ENG)  2022-2023       12    20         1  1181
# 3      AC Voges (AUS)  2015-2016       20    31         7  1485
# 4     RG Pollock (SA)  1963-1970       23    41         4  2256
# 5     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 63   KD Walters (AUS)  1965-1981       74   125        14  5357
# 64  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 65  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 66    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 67   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
df=df.drop(columns="Span")

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score  \
# 0    DG Bradman (AUS)       52    80        10  6996                334
# 2      HC Brook (ENG)       12    20         1  1181                186
# 3      AC Voges (AUS)       20    31         7  1485               269*
# 4     RG Pollock (SA)       23    41         4  2256                274
# 5     GA Headley (WI)       22    40         4  2190               270*
# ..                ...      ...   ...       ...   ...                ...
# 63   KD Walters (AUS)       74   125        14  5357                250
# 64  GC Smith (ICC/SA)      117   205        13  9265                277
# 65  WH Ponsford (AUS)       29    48         4  2122                266
# 66    SJ McCabe (AUS)       39    62         5  2748                232
# 67   DR Jardine (ENG)       22    33         6  1296                127
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
#lets separate country code from the player name
df['Player'].str.split(pat="(")
# Out:
# 0      [DG Bradman , AUS)]
# 2        [HC Brook , ENG)]
# 3        [AC Voges , AUS)]
# 4       [RG Pollock , SA)]
# 5       [GA Headley , WI)]
#               ...
# 63     [KD Walters , AUS)]
# 64    [GC Smith , ICC/SA)]
# 65    [WH Ponsford , AUS)]
# 66      [SJ McCabe , AUS)]
# 67     [DR Jardine , ENG)]
# Name: Player, Length: 64, dtype: object

# %%
df["Country"]=df["Player"].str.split(pat="(").str[1]

# %%
df["Player"]=df["Player"].str.split(pat="(").str[0]

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                334  99.94
# 2      HC Brook        12    20         1  1181                186  62.15
# 3      AC Voges        20    31         7  1485               269*  61.87
# 4    RG Pollock        23    41         4  2256                274  60.97
# 5    GA Headley        22    40         4  2190               270*  60.83
# ..           ...      ...   ...       ...   ...                ...    ...
# 63   KD Walters        74   125        14  5357                250  48.26
# 64     GC Smith       117   205        13  9265                277  48.25
# 65  WH Ponsford        29    48         4  2122                266  48.22
# 66    SJ McCabe        39    62         5  2748                232  48.21
# 67   DR Jardine        22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df["Country"]=df["Country"].str.replace(")","")

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                334  99.94
# 2      HC Brook        12    20         1  1181                186  62.15
# 3      AC Voges        20    31         7  1485               269*  61.87
# 4    RG Pollock        23    41         4  2256                274  60.97
# 5    GA Headley        22    40         4  2190               270*  60.83
# ..           ...      ...   ...       ...   ...                ...    ...
# 63   KD Walters        74   125        14  5357                250  48.26
# 64     GC Smith       117   205        13  9265                277  48.25
# 65  WH Ponsford        29    48         4  2122                266  48.22
# 66    SJ McCabe        39    62         5  2748                232  48.21
# 67   DR Jardine        22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
#fixing the Highest Innings Score's dtype to int
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df["Highest_Inns_Score"].str.split(pat="*").str[0]
# Out:
# 0     334
# 2     186
# 3     269
# 4     274
# 5     270
#      ...
# 63    250
# 64    277
# 65    266
# 66    232
# 67    127
# Name: Highest_Inns_Score, Length: 64, dtype: object

# %%
df["Highest_Inns_Score"]=df["Highest_Inns_Score"].str.split(pat="*").str[0]

# %%
df["Highest_Inns_Score"]
# Out:
# 0     334
# 2     186
# 3     269
# 4     274
# 5     270
#      ...
# 63    250
# 64    277
# 65    266
# 66    232
# 67    127
# Name: Highest_Inns_Score, Length: 64, dtype: object

# %%
df["Highest_Inns_Score"]=df["Highest_Inns_Score"].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
#fixing the rookie and final year dtype
df=df.astype({'Rookie_Year':'int','Final_Year':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
#fixing balls faced
df["Balls_Faced"]=df["Balls_Faced"].str.split(pat="+").str[0]

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                 Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0          DG Bradman        52    80        10   6996                 334
# 2            HC Brook        12    20         1   1181                 186
# 3            AC Voges        20    31         7   1485                 269
# 4          RG Pollock        23    41         4   2256                 274
# 5          GA Headley        22    40         4   2190                 270
# 6         H Sutcliffe        54    84         9   4555                 194
# 7           E Paynter        20    31         5   1540                 243
# 8       KF Barrington        82   131        15   6806                 256
# 10          ED Weekes        48    81         5   4455                 207
# 11          SPD Smith       102   181        22   9320                 239
# 12         WR Hammond        85   140        16   7249                 336
# ...

# %%
df["Balls_Faced"]=df['Balls_Faced'].fillna(0)

# %%
df
# Out:
#                 Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0          DG Bradman        52    80        10   6996                 334
# 2            HC Brook        12    20         1   1181                 186
# 3            AC Voges        20    31         7   1485                 269
# 4          RG Pollock        23    41         4   2256                 274
# 5          GA Headley        22    40         4   2190                 270
# 6         H Sutcliffe        54    84         9   4555                 194
# 7           E Paynter        20    31         5   1540                 243
# 8       KF Barrington        82   131        15   6806                 256
# 10          ED Weekes        48    81         5   4455                 207
# 11          SPD Smith       102   181        22   9320                 239
# 12         WR Hammond        85   140        16   7249                 336
# ...

# %%
df["Balls_Faced"]=df["Balls_Faced"].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
#find Career length of each of them
df["career_length"]=df["Final_Year"]-df["Rookie_Year"]

# %%
df
# Out:
#                 Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0          DG Bradman        52    80        10   6996                 334
# 2            HC Brook        12    20         1   1181                 186
# 3            AC Voges        20    31         7   1485                 269
# 4          RG Pollock        23    41         4   2256                 274
# 5          GA Headley        22    40         4   2190                 270
# 6         H Sutcliffe        54    84         9   4555                 194
# 7           E Paynter        20    31         5   1540                 243
# 8       KF Barrington        82   131        15   6806                 256
# 10          ED Weekes        48    81         5   4455                 207
# 11          SPD Smith       102   181        22   9320                 239
# 12         WR Hammond        85   140        16   7249                 336
# ...

# %%
#Average career length
df["career_length"].mean()
# Out:
# 12.75

# %%
#Average batting strike rate for cricketers who played over 10 years
df[df["career_length"]>10]['Batting_Strike_Rate'].mean()
# Out:
# 47.95454545454545

# %%
#No. of cricketers who played before 1960
df[df['Rookie_Year']<1960]
# Out:
#              Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0       DG Bradman        52    80        10  6996                 334  99.94
# 5       GA Headley        22    40         4  2190                 270  60.83
# 6      H Sutcliffe        54    84         9  4555                 194  60.73
# 7        E Paynter        20    31         5  1540                 243  59.23
# 8    KF Barrington        82   131        15  6806                 256  58.67
# 10       ED Weekes        48    81         5  4455                 207  58.61
# 12      WR Hammond        85   140        16  7249                 336  58.45
# 13       GS Sobers        93   160        21  8032                 365  57.78
# 16        JB Hobbs        61   102         7  5410                 211  56.94
# 17      CL Walcott        44    74         7  3798                 220  56.68
# 18        L Hutton        79   138        15  6971                 364  56.67
# ...

# %%
#Max highest inns score by country
df.groupby('Country')["Highest_Inns_Score"].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_Score, dtype: int32

# %%
#we can also label it and sort it
df.groupby('Country')["Highest_Inns_Score"].max().to_frame('High_Inns_for_Country').reset_index().sort_values('High_Inns_for_Country',ascending=False)
# Out:
#     Country  High_Inns_for_Country
# 5    ICC/WI                    400
# 0       AUS                    380
# 10       SL                    374
# 11       WI                    365
# 1       ENG                    364
# 3   ICC/PAK                    329
# 2   ICC/IND                    319
# 8       PAK                    313
# 9        SA                    278
# 4    ICC/SA                    277
# 6       IND                    254
# 7        NZ                    251
# 12      ZIM                    232

# %%
#Average hundreds, fifties and ducks by each country
df.groupby('Country')["100","50","0"].mean()
# Out:
# C:\Users\Tushnik\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                100         50          0
# Country
# AUS      20.625000  28.000000   8.500000
# ENG      12.307692  20.769231   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.250000  10.750000
# NZ       12.333333  16.333333   4.333333
# PAK      17.800000  23.200000   8.000000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
